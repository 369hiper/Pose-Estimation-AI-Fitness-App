# %%
# %pip install opencv-python
# %pip install mediapipe

import cv2
import mediapipe as mp
import numpy as np

# %%
#  Broadcasting raw webcam feed

cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, Image = cap.read()
    cv2.imshow('Raw Webcam feed', Image)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# mp_face_detection = mp.solutions.face_detection.FaceDetection(min_detection_confidence=0.2)
# mp_drawing = mp.solutions.drawing_utils
# mp_drawing_styles = mp.solutions.drawing_styles 

#  Broadcasting raw webcam feed

cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, Image = cap.read()
    cv2.imshow('Raw Webcam feed', Image)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.10.21-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: absl-py in .\.venv\lib\site-packages (from mediapipe) (2.2.2)
# Requirement already satisfied: attrs>=19.1.0 in .\.venv\lib\site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in .\.venv\lib\site-packages (from mediapipe) (25.2.10)
# Collecting jax (from mediapipe)
#   Using cached jax-0.5.3-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib (from mediapipe)
#   Using cached jaxlib-0.5.3-cp312-cp312-win_amd64.whl.metadata (1.2 kB)
# Collecting matplotlib (from mediapipe)
#   Using cached matplotlib-3.10.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2 in .\.venv\lib\site-packages (from mediapipe) (1.26.4)
# Collecting opencv-contrib-python (from mediapipe)
#   Using cached opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: protobuf<5,>=4.25.3 in .\.venv\lib\site-packages (from mediapipe) (4.25.6)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Using cached sounddevice-0.5.1-py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in .\.venv\lib\site-packages (from mediapipe) (0.2.0)
# Collecting CFFI>=1.0 (from sounddevice>=0.4.4->mediapipe)
#   Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata (1.6 kB)
# Collecting ml_dtypes>=0.4.0 (from jax->mediapipe)
#   Using cached ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: opt_einsum in .\.venv\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in .\.venv\lib\site-packages (from jax->mediapipe) (1.15.2)
# Collecting contourpy>=1.0.1 (from matplotlib->mediapipe)
#   Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: cycler>=0.10 in .\.venv\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.venv\lib\site-packages (from matplotlib->mediapipe) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\lib\site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in .\.venv\lib\site-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in .\.venv\lib\site-packages (from matplotlib->mediapipe) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in .\.venv\lib\site-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in .\.venv\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in .\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Using cached mediapipe-0.10.21-cp312-cp312-win_amd64.whl (51.0 MB)
# Using cached sounddevice-0.5.1-py3-none-win_amd64.whl (363 kB)
# Using cached jax-0.5.3-py3-none-any.whl (2.4 MB)
# Using cached jaxlib-0.5.3-cp312-cp312-win_amd64.whl (65.8 MB)
# Using cached matplotlib-3.10.1-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl (46.2 MB)
# Using cached cffi-1.17.1-cp312-cp312-win_amd64.whl (181 kB)
# Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl (210 kB)
# Installing collected packages: opencv-contrib-python, ml_dtypes, contourpy, CFFI, sounddevice, matplotlib, jaxlib, jax, mediapipe
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'h:\\llm_projects\\12-deadlift-vision\\.venv\\Lib\\site-packages\\cv2\\cv2.pyd'
# Check the permissions.

# %%
# MEdiapipe Pose Estimation
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

cap = cv2.VideoCapture(0)
with mp_pose.Pose(min_detection_confidence=0.1, min_tracking_confidence=0.1) as pose:
    while cap.isOpened():
        ret, Image = cap.read()
        cv2.imshow('Media pipe pose detection', Image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# MEdiapipe Pose Estimation
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

cap = cv2.VideoCapture(0)
with mp_pose.Pose(min_detection_confidence=0.1, min_tracking_confidence=0.1) as pose:
    while cap.isOpened():
        ret, Image = cap.read()
        Image = cv2.cvtColor(Image, cv2.COLOR_BGR2RGB)
        Image.flags.writeable = False
        results = pose.process(Image)
        Image.flags.writeable = True
        Image = cv2.cvtColor(Image, cv2.COLOR_RGB2BGR)  # Re-enable color conversion
        mp_drawing.draw_landmarks(Image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                   mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=6, circle_radius=4),
                                   mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=4, circle_radius=2))
        cv2.imshow('Media pipe pose detection', Image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# echo "# Pose-Estimation-AI-Fitness-App" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/369hiper/Pose-Estimation-AI-Fitness-App.git
# git push -u origin main



mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, Image = cap.read()
    if not ret:
        break

    Image_rgb = cv2.cvtColor(Image, cv2.COLOR_BGR2RGB)

    # Process the image to detect poses
    results = pose.process(Image_rgb)

    # Draw the pose landmarks on the image
    if results.pose_landmarks:
        mp_drawing.draw_landmarks(
            Image, 
            results.pose_landmarks, 
            mp_pose.POSE_CONNECTIONS
        )

    # Display the image with pose landmarks
    cv2.imshow('Pose Detection', Image)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
